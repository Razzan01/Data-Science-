# %% [markdown]
# <a href="https://colab.research.google.com/github/Razzan01/Data-Science-/blob/main/ASSIGNMENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RAZZAN HARITH MOHAMMED
#
# SCM221-0003/2021
#
#
# # **CANCER CASES & DEATHS AS ATTRIBUTED TO VARIOUS FACTORS**
#
#
# ### **BUSINESS UNDERSTANDING:**
# The primary objective of this data analysis is to understand how various factors contribute to the prevalence of cancer related cases and deaths.This will enable healthcare providers,policymakers and researchers to develop targeted prevention and intervention strategies to reduce cancer incidence and mortality.

# %% [markdown]
# **DATA LOADING**

# %%
#Install LIbraries
import pandas as pd
#Defining file path
#fp=/content/Cancer.xlsx
#Loading Dataset
fp=pd.read_excel("/content/Cancer.xlsx")
fp
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %% [markdown]
# The dataset comprises of 27 columns with data of different countries with the types of cancer,cause and their prevalence in male and female and the risk factors that contribute to cancer

# %%
#Dataset Information
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                     --------------  -----
#  0   Country or Territory                                                                                                                                       207 non-null    object
#  1   Cancer deaths attributable to alcohol
# Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016                       207 non-null    object
#  2   Smoking prevalence male
# ...

# %% [markdown]
# The info above shows the columns, the data type and the memory capacity

# %%
from tabulate import tabulate
#Get all column names
column_names=fp.columns.tolist()
#Convert column names to a list
column_names_table=[[i+1,name]for i,name in enumerate(column_names)]
#Print column names
print(tabulate(column_names_table,headers=["Index","Column Name"]))
# Out:
#   Index  Column Name
# -------  -----------------------------------------------------------------------------------------------------------------------------------
#       1  Country or Territory
#       2  Cancer deaths attributable to alcohol
#          Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016
#       3  Smoking prevalence male
#          Prevalence (%) of daily smoking for men
#       4  Smoking prevalence female
#          Prevalence (%) of daily smoking for women
#       5  Cancers attributable to infections
#          Proportion of cancers attributable to infections (%), by country
#       6  Obesity prevalence male
#          International variation in the prevalence of obesity, 2016
#       7  Obesity prevalence female
#          International variation in the prevalence of obesity, 2016
#       8  Melanoma skin cancer incidence
#          Age-standardized rate (world) per 100,000, both sexes, 2018
# ...

# %%
print(fp.shape)
# Out:
# (207, 27)

# %% [markdown]
# This shows that there are 207 rows and 27 columns

# %%
#Displayng the first few rows
fp.head()
# Out:
#   Country or Territory  \
# 0          Afghanistan
# 1              Algeria
# 2           Azerbaijan
# 3              Albania
# 4              Armenia
#
#   Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                0.5
# 1                                                1.1
# 2                                                3.2
# 3                                                4.9
# 4                                                  5
#
#   Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                               21.4
# 1                                               17.5
# 2                                               36.7
# 3                                               40.9
# 4                                               43.5
#
#   Smoking prevalence female\nPrevalence (%) of daily smoking for women  \
# ...

# %% [markdown]
# This shows the first five rows of the dataset

# %%
fp.tail()
# Out:
#     Country or Territory  \
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
#     Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
# ...

# %% [markdown]
# This shows the last five rows of the dataset

# %%
#Selecting relevant columns
Relevant_columns= [
'Country or Territory',
'Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016',
'Smoking prevalence male\nPrevalence (%) of daily smoking for men',
'Smoking prevalence female\nPrevalence (%) of daily smoking for women',
'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016',
'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
'Cancer rank as leading cause of death among 30-69\n2016',
'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018',
'Breast most frequently diagnosed cancer in women\nCountries where breast cancer is the most frequently diagnosed cancer in women, 2018',
'Most common cancer cases worldwide, females\n2018',
'Most common cancer deaths worldwide, females\n2018',
'Most common cancer cases worldwide, males\n2018',
'Most common cancer deaths worldwide, males\n2018',
'Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
'Radiotherapy availability\nNumber of radiotherapy machines per 1,000 cancer patients',
'Cervical cancer incidence rates\nAge-standardized rate (world) per 100,000, 2018',
]
Relevant_fp=fp[Relevant_columns]
Relevant_fp
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %%
#Display the data types of columns
print("\nData types of columns in Relevant_fp:")
print(Relevant_fp.dtypes)
# Out:
# Data types of columns in Relevant_fp:
# Country or Territory                                                                                                                      object
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016     object
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                          object
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                      object
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                      object
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                       object
# ...

# %% [markdown]
# This shows that the data type is object hence changing to numeric will be more suitable

# %%
Relevant_numeric_columns=[
'Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016',
'Smoking prevalence male\nPrevalence (%) of daily smoking for men',
'Smoking prevalence female\nPrevalence (%) of daily smoking for women',
'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016',
'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018',
'Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
'Radiotherapy availability\nNumber of radiotherapy machines per 1,000 cancer patients',
'Cervical cancer incidence rates\nAge-standardized rate (world) per 100,000, 2018',
]
Numeric_Relevant_fp=Relevant_fp[Relevant_numeric_columns]
Numeric_Relevant_fp
# Out:
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
#     Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                                 21.4
# 1                                                 17.5
# ...

# %%
#Change all columns to numeric types
Numeric_Relevant_fp=Numeric_Relevant_fp.apply(pd.to_numeric,errors='coerce')
#Print the dataframe
print(Numeric_Relevant_fp)
# Out:
#      Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                  5.0
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#      Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                                 21.4
# 1                                                 17.5
# ...

# %%
#Display the data types of columns
print("\nData types of columns in Numeric_Relevant_fp:")
print(Numeric_Relevant_fp.dtypes)
# Out:
# Data types of columns in Numeric_Relevant_fp:
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    float64
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                         float64
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                     float64
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                     float64
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                      float64
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                                                    float64
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
#Check for missing values
Numeric_Relevant_fp.isnull()
Numeric_Relevant_fp.isnull().sum()
print(Numeric_Relevant_fp.isnull().sum())
# Out:
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    23
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                         18
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                     16
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                     23
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                      16
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                                                    16
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                             22
# ...

# %% [markdown]
# There are missing values in the data

# %%
#Drop missing values
Numeric_Relevant_fp.dropna(subset=Relevant_numeric_columns,inplace=True)

# %%
#Check if all missing values have been removed
missing_values=Relevant_fp.isnull().sum()
print(missing_values)
# Out:
# Country or Territory                                                                                                                      0
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016     0
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                          0
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                      0
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                      0
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                       0
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                                                     0
# ...

# %% [markdown]
# All the missing values in the data have been removed

# %%
#Check for duplicates
duplicates=Numeric_Relevant_fp.duplicated().sum()
print(duplicates)
# Out:
# 3

# %%
#Drop the duplicates
Numeric_Relevant_fp.drop_duplicates(inplace=True)

# %%
#Check if all the duplicates have been dropped
duplicates=Numeric_Relevant_fp.duplicated().sum()
print(duplicates)
# Out:
# 0

# %% [markdown]
# All the duplicates have been removed

# %%
#Completeness
completeness=Numeric_Relevant_fp.notnull().sum()/len(Numeric_Relevant_fp)*100
print(completeness)
# Out:
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    100.0
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                         100.0
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                     100.0
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                     100.0
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                      100.0
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                                                    100.0
# ...

# %% [markdown]
# The data is complete for further analysis

# %%
#Check for the data shape after cleaning
print(Numeric_Relevant_fp.shape)
# Out:
# (168, 11)

# %% [markdown]
# **E.D.A**

# %%
#Compute the descriptive statistics for the data
print(Numeric_Relevant_fp.describe())
# Out:
#        Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# count                                         168.000000
# mean                                            5.373810
# std                                             2.959735
# min                                             0.200000
# 25%                                             2.975000
# 50%                                             5.350000
# 75%                                             7.425000
# max                                            14.500000
#
#        Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# count                                         168.000000
# mean                                           24.158929
# std                                            11.392215
# min                                             4.400000
# 25%                                            14.850000
# ...

# %% [markdown]
# This gives the summary statistics of the data

# %%
#Correlation
import seaborn as sns
import matplotlib.pyplot as plt
#Calculate correlation matrix
correlation_matrix=Numeric_Relevant_fp.corr()
correlation_matrix
# Out:
#                                                     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# Cancer deaths attributable to alcohol\nProporti...                                           1.000000
# Smoking prevalence male\nPrevalence (%) of dail...                                           0.110396
# Smoking prevalence female\nPrevalence (%) of da...                                           0.358587
# Cancers attributable to infections\nProportion ...                                          -0.086535
# Obesity prevalence male\nInternational variatio...                                           0.102708
# Obesity prevalence female\nInternational variat...                                          -0.136756
# Lung cancer incidence rates, male\nAge-standard...                                           0.438107
# ...

# %%
#Creating Histograms
for col in Numeric_Relevant_fp:
  plt.figure()
  plt.hist(Numeric_Relevant_fp[col],bins=10)
  plt.xlabel(col)
  plt.ylabel("Frequency")
  plt.title(f"Histogram of {col}")
  plt.show()

# %%
#Create Heatmap for Correlation
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
#Most Common cancer cases woldwide,females 2018 vs Most common cancer deaths worldwide,females 2018
plt.subplots(figsize=(8,8))
df_fem=pd.DataFrame({
    x_label:grp['Most common cancer cases worldwide, females\n2018'].value_counts()
    for x_label,grp in Relevant_fp.groupby('Most common cancer deaths worldwide, females\n2018')
})
sns.heatmap(df_fem,cmap='viridis')
plt.xlabel('Most common cancer cases worldwide, females\n2018')
plt.ylabel('Most common cancer deaths worldwide, females\n2018')
# Out:
# Text(70.72222222222221, 0.5, 'Most common cancer deaths worldwide, females\n2018')

# %%
#Most common cancer deaths worldwide,females 2018
Relevant_fp.groupby('Most common cancer deaths worldwide, females\n2018').size().plot(kind='barh',color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top','right',]].set_visible(False)

# %%
#Most common cancer cases worldwide,females 2018
Relevant_fp.groupby('Most common cancer cases worldwide, females\n2018').size().plot(kind='barh',color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top','right',]].set_visible(False)

# %%
#Most Common cancer cases woldwide,males 2018 vs Most common cancer deaths worldwide,males 2018
plt.subplots(figsize=(8,8))
df_fem=pd.DataFrame({
    x_label:grp['Most common cancer cases worldwide, males\n2018'].value_counts()
    for x_label,grp in Relevant_fp.groupby('Most common cancer deaths worldwide, males\n2018')
})
sns.heatmap(df_fem,cmap='viridis')
plt.xlabel('Most common cancer cases worldwide, males\n2018')
plt.ylabel('Most common cancer deaths worldwide, males\n2018')
# Out:
# Text(70.7222222222222, 0.5, 'Most common cancer deaths worldwide, males\n2018')

# %%
#Most common cancer deaths worldwide,males 2018
Relevant_fp.groupby('Most common cancer deaths worldwide, males\n2018').size().plot(kind='barh',color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top','right',]].set_visible(False)

# %%
#Most common cancer cases worldwide,males 2018
Relevant_fp.groupby('Most common cancer cases worldwide, males\n2018').size().plot(kind='barh',color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top','right',]].set_visible(False)

# %% [markdown]
# **FINDINGS**
#
# 1.Males have more cases of lung cancer than females and they also have more deaths due to lung cancer than females
#
# 2.Prostate cancer is the most leading cancer case in males while breast cancer is the leading cancer case in females
#
# 3.Females with lung cancer are most likely to survive than males with lung cancer
#
# 4.Men with obesity are more likely to survive cancer than women with obesity
#
# 5.Radiotherapy availability was more beneficial to women who smoke than men

# %% [markdown]
# **CONCLUSION**
#
# According to the findings men should reduce and if possible avoid smoking so as to reduce their chances of contracting cancer.
# Radiotherapy machines should be increased so as to increase the number of cancer survivors.
# Women should go for breast cancer screening so as to detect the cancer early and treat it.This could help to find and trat the breast cancer as early as possible.
# It is also of need to bring awareness to the people on cancer as most people have been ignorant about it.
